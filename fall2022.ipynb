# %%
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD

# %%
model = BayesianNetwork([('D', 'G'), ('I', 'G'), ('G', 'L'), ('I', 'S')])

# %%
import networkx as nx
G_sylb = nx.Graph()

# %%
G_sylb.add_node("naʊ")

# %%
nx.draw(G_sylb)

# %%
G_sylb.add_node(0)

# %%
G_sylb.add_node(1)

# %%
nx.draw(G_sylb)

# %%
G_sylb.add_edge(0,1)
G_sylb.add_edge("naʊ", 1)
G_sylb.add_edge("naʊ", 0)

# %%
nx.draw(G_sylb)

# %%
caliLoveGraph = nx.DiGraph()

# %%
caliLoveGraph.add_node(G_sylb)

# %%
G_sylb_2 = nx.Graph()

# %%
G_sylb_2.add_node(1)

# %%
G_sylb_2.add_node(1)

# %%
G_sylb_2.add_node("lɜt")

# %%
G_sylb_2.add_edge(1,1)
G_sylb_2.add_edge("lɜt", 1)

# %%
nx.draw(G_sylb_2)

# %%
caliLoveGraph.add_node(G_sylb_2)

# %%
caliLoveGraph.add_edge(G_sylb, G_sylb_2, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_3 = nx.Graph()

# %%
G_sylb_3.add_node("mi")

# %%
G_sylb_3.add_node(1)

# %%
G_sylb_3.add_node(0)

# %%
G_sylb_3.add_edge(0,1)

# %%
G_sylb_3.add_edge(1,"mi")

# %%
G_sylb_3.add_edge(0, "mi")

# %%
nx.draw(G_sylb_3)

# %%
caliLoveGraph.add_edge(G_sylb_2, G_sylb_3, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_4 = nx.Graph()

# %%
G_sylb_4.add_node("wɜl")

# %%
G_sylb_4.add_node(1)

# %%
G_sylb_4.add_node(1)

# %%
G_sylb_4.add_edge(1,1)

# %%
G_sylb_4.add_edge(1,"wɜl")

# %%
nx.draw(G_sylb_4)

# %%
caliLoveGraph.add_node(G_sylb_4)

# %%
nx.draw(caliLoveGraph)

# %%
caliLoveGraph.add_edge(G_sylb_3, G_sylb_4, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_5 = nx.Graph()

# %%
G_sylb_5.add_node("kəm")

# %%
G_sylb_5.add_node(0)

# %%
G_sylb_5.add_node(1)

# %%
G_sylb_5.add_edge(0,1)

# %%
G_sylb_5.add_edge("kəm", 1)

# %%
G_sylb_5.add_edge("kəm", 0)

# %%
nx.draw(G_sylb_5)

# %%
caliLoveGraph.add_node(G_sylb_5)

# %%
nx.draw(caliLoveGraph)

# %%
caliLoveGraph.add_edge(G_sylb_4, G_sylb_5, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_6 = nx.Graph()

# %%
G_sylb_6.add_node(1)

# %%
G_sylb_6.add_node(1)

# %%
G_sylb_6.add_node("ɜ")

# %%
G_sylb_6.add_edge("ɜ", 1)

# %%
G_sylb_6.add_edge(1,1)

# %%
nx.draw(G_sylb_6)

# %%
caliLoveGraph.add_node(G_sylb_6)

# %%
caliLoveGraph.add_edge(G_sylb_5, G_sylb_6, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_7 = nx.Graph()

# %%
G_sylb_7.add_node(1)

# %%
G_sylb_7.add_node("vrI")

# %%
G_sylb_7.add_node(0)

# %%
G_sylb_7.add_edge(0,1)

# %%
G_sylb_7.add_edge(1, "vrI")

# %%
G_sylb_7.add_edge(0, "vrI")

# %%
nx.draw(G_sylb_7)

# %%
caliLoveGraph.add_node(G_sylb_7)

# %%
caliLoveGraph.add_edge(G_sylb_6, G_sylb_7, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_8 = nx.Graph()

# %%
G_sylb_8.add_node("bə")

# %%
G_sylb_8.add_node(1)

# %%
G_sylb_8.add_node(1)

# %%
G_sylb_8.add_edge(1,1)

# %%
G_sylb_8.add_edge(1, "bə")

# %%
nx.draw(G_sylb_8)

# %%
caliLoveGraph.add_node(G_sylb_8)

# %%
caliLoveGraph.add_edge(G_sylb_7, G_sylb_8, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_9 = nx.Graph()

# %%
G_sylb_9.add_node("di")

# %%
G_sylb_9.add_node(1)

# %%
G_sylb_9.add_node(0)

# %%
G_sylb_9.add_edge(0,1)

# %%
G_sylb_9.add_edge(0,"di")

# %%
G_sylb_9.add_edge(1, "di")

# %%
nx.draw(G_sylb_9)

# %%
caliLoveGraph.add_node(G_sylb_9)

# %%
caliLoveGraph.add_edge(G_sylb_8, G_sylb_9, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_10 = nx.Graph()

# %%
G_sylb_10.add_node("tu")

# %%
G_sylb_10.add_node(1)

# %%
G_sylb_10.add_edge(1,1)

# %%
G_sylb_10.add_edge("tu",1)

# %%
nx.draw(G_sylb_10)

# %%
caliLoveGraph.add_node(G_sylb_10)

# %%
caliLoveGraph.add_edge(G_sylb_9, G_sylb_10, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_11 = nx.Graph()

# %%
G_sylb_11.add_node("ðə")

# %%
G_sylb_11.add_node(1)

# %%
G_sylb_11.add_node(0)

# %%
G_sylb_11.add_edge(0,1)
G_sylb_11.add_edge(0, "ðə")
G_sylb_11.add_edge(1, "ðə")

# %%
nx.draw(G_sylb_11)

# %%
caliLoveGraph.add_node(G_sylb_11)

# %%
caliLoveGraph.add_edge(G_sylb_10, G_sylb_11, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_12 = nx.Graph()

# %%
G_sylb_12.add_node(1)

# %%
G_sylb_12.add_node("waIld")

# %%
G_sylb_12.add_edge(1,1)

# %%
G_sylb_12.add_edge("waIld",1)

# %%
nx.draw(G_sylb_12)

# %%
caliLoveGraph.add_node(G_sylb_12)

# %%
caliLoveGraph.add_edge(G_sylb_11, G_sylb_12, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_13 = nx.Graph()

# %%
G_sylb_13.add_node(1)

# %%
G_sylb_13.add_node("waIld")

# %%
G_sylb_13.add_edge(1,1)

# %%
G_sylb_13.add_edge(1,"waIld")

# %%
caliLoveGraph.add_node(G_sylb_13)

# %%
caliLoveGraph.add_edge(G_sylb_12, G_sylb_13, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_14 = nx.Graph()

# %%
G_sylb_14.add_node(1)

# %%
G_sylb_14.add_node(1)

# %%
nx.draw(G_sylb_14)

# %%
G_sylb_14.add_node("wɜst")

# %%
G_sylb_14.add_edge("wɜst", 1)
G_sylb_14.add_edge(1, 1)

# %%
nx.draw(G_sylb_14)

# %%
caliLoveGraph.add_node(G_sylb_14)

# %%
caliLoveGraph.add_edge(G_sylb_13, G_sylb_14, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_15 = nx.Graph()

# %%
G_sylb_15.add_node(2)

# %%
G_sylb_15.add_node(0)
G_sylb_15.add_node("ə")

# %%
G_sylb_15.add_edge("ə", 0)
G_sylb_15.add_edge("ə", 1)
G_sylb_15.add_edge(1, 0)

# %%
caliLoveGraph.add_node(G_sylb_15)

# %%
caliLoveGraph.add_edge(G_sylb_14, G_sylb_15, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_16 = nx.Graph()

# %%
G_sylb_16.add_node("steIt")

# %%
G_sylb_16.add_node(2)

# %%
G_sylb_16.add_node(1)

# %%
G_sylb_16.add_edge(1, 2)
G_sylb_16.add_edge("steIt", 2)
G_sylb_16.add_edge("steIt",1)

# %%
nx.draw(G_sylb_16)

# %%
caliLoveGraph.add_node(G_sylb_16)

# %%
caliLoveGraph.add_edge(G_sylb_15, G_sylb_16, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_17 = nx.Graph()
G_sylb_17.add_node(2)
G_sylb_17.add_node("ðæts")
G_sylb_17.add_node(1)
G_sylb_17.add_edge("ðæts", 1)
G_sylb_17.add_edge("ðæts", 2)
G_sylb_17.add_edge(1,2)

# %%
nx.draw(G_sylb_17)

# %%
caliLoveGraph.add_node(G_sylb_17)
caliLoveGraph.add_edge(G_sylb_16, G_sylb_17, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_18 = nx.Graph()
G_sylb_18.add_node(2)
G_sylb_18.add_node(0)
G_sylb_18.add_node("ən")
G_sylb_18.add_edge(2, "ən")
G_sylb_18.add_edge(0, "ən")
G_sylb_18.add_edge(0, 2)

# %%
nx.draw(G_sylb_18)

# %%
caliLoveGraph.add_node(G_sylb_18)
caliLoveGraph.add_edge(G_sylb_17, G_sylb_18, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_19 = nx.Graph()

# %%
G_sylb_19.add_node("tə")
G_sylb_19.add_node(1)
G_sylb_19.add_node(2)
G_sylb_19.add_edge(1,2)
G_sylb_19.add_edge("tə", 2)
G_sylb_19.add_edge("tə", 1)

# %%
nx.draw(G_sylb_19)

# %%
caliLoveGraph.add_node(G_sylb_19)

# %%
caliLoveGraph.add_edge(G_sylb_18, G_sylb_19, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_20 = nx.Graph()

# %%
G_sylb_20.add_node("tʃə")
G_sylb_20.add_node(2)
G_sylb_20.add_node(0)
G_sylb_20.add_edge("tʃə", 2)
G_sylb_20.add_edge(0,2)
G_sylb_20.add_edge("tʃə",0)

# %%
nx.draw(G_sylb_20)

# %%
caliLoveGraph.add_node(G_sylb_20)
caliLoveGraph.add_edge(G_sylb_19, G_sylb_20, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_21 = nx.Graph()
G_sylb_21.add_node("bl")
G_sylb_21.add_node(2)
G_sylb_21.add_node(0)

# %%
G_sylb_21.add_edge(0,2)
G_sylb_21.add_edge("bl",2)
G_sylb_21.add_edge("bl",0)

# %%
caliLoveGraph.add_node(G_sylb_21)
caliLoveGraph.add_edge(G_sylb_20, G_sylb_21, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_22 = nx.Graph()
G_sylb_22.add_node("laIk")
G_sylb_22.add_node(0)
G_sylb_22.add_node(2)
G_sylb_22.add_edge(0,2)
G_sylb_22.add_edge("laIk",2)
G_sylb_22.add_edge("laIk",0)

# %%
caliLoveGraph.add_node(G_sylb_22)
caliLoveGraph.add_edge(G_sylb_21, G_sylb_22, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_23 = nx.Graph()
G_sylb_23.add_node("ɜ")
G_sylb_23.add_node(1)
G_sylb_23.add_node(2)
G_sylb_23.add_edge(1,2)
G_sylb_23.add_edge("ɜ",2)
G_sylb_23.add_edge("ɜ",1)

# %%
caliLoveGraph.add_node(G_sylb_23)

# %%
caliLoveGraph.add_edge(G_sylb_22, G_sylb_23, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_24 = nx.Graph()
G_sylb_24.add_node(2)
G_sylb_24.add_node(0)
G_sylb_24.add_node("li")
G_sylb_24.add_edge("li", 0)
G_sylb_24.add_edge("li", 2)
G_sylb_24.add_edge(0,2)

# %%
caliLoveGraph.add_node(G_sylb_24)
caliLoveGraph.add_edge(G_sylb_23, G_sylb_24, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
G_sylb_25 = nx.Graph()
G_sylb_25.add_node("ət")
G_sylb_25.add_node(0)
G_sylb_25.add_node(2)
G_sylb_25.add_edge(0,2)
G_sylb_25.add_edge(0, "ət")
G_sylb_25.add_edge(2, "ət")

# %%
caliLoveGraph.add_node(G_sylb_25)
caliLoveGraph.add_edge(G_sylb_24, G_sylb_25, weight = 0)

# %%
G_sylb_26 = nx.Graph()
G_sylb_26.add_node(2)
G_sylb_26.add_node(1)
G_sylb_26.add_node("nɜs")
G_sylb_26.add_edge("nɜs",2)
G_sylb_26.add_edge("nɜs",1)
G_sylb_26.add_edge(1, 2)

# %%
nx.draw(G_sylb_26)

# %%
caliLoveGraph.add_node(G_sylb_26)
caliLoveGraph.add_edge(G_sylb_25, G_sylb_26, weight = 0)

# %%
nx.draw(caliLoveGraph)

# %%
caliLoveGraph.add_edge(G_sylb_14, G_sylb_26, weight = 1)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw(caliLoveGraph, pos, with_labels=False, connectionstyle='arc3, rad = 0.1')

# %%
len(caliLoveGraph.in_edges(G_sylb_26))
# Out:
# 2

# %%
G_sylb_3_1 = nx.Graph()
G_sylb_3_1.add_node("ðə")
G_sylb_3_1.add_node(0)
G_sylb_3_1.add_node(3)
G_sylb_3_1.add_edge(0,3)
G_sylb_3_1.add_edge("ðə",3)
G_sylb_3_1.add_edge("ðə",0)

# %%
caliLoveGraph.add_node(G_sylb_3_1)

# %%
caliLoveGraph.add_edge(G_sylb_26, G_sylb_3_1, weight = 0)

# %%
G_sylb_3_2 = nx.Graph()
G_sylb_3_2.add_node("træk")
G_sylb_3_2.add_node(3)
G_sylb_3_2.add_node(1)
G_sylb_3_2.add_edge(3,1)
G_sylb_3_2.add_edge("træk",3)
G_sylb_3_2.add_edge("træk", 1)

# %%
caliLoveGraph.add_node(G_sylb_3_2)
caliLoveGraph.add_edge(G_sylb_3_1, G_sylb_3_2, weight = 0)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw(caliLoveGraph, pos, with_labels=False, connectionstyle='arc3, rad = 0.2')

# %%
G_sylb_3_3 = nx.Graph()
G_sylb_3_3.add_node(3)
G_sylb_3_3.add_node("hIts")
G_sylb_3_3.add_node(1)
G_sylb_3_3.add_edge(3,1)
G_sylb_3_3.add_edge("hIts", 3)
G_sylb_3_3.add_edge("hIts", 1)

# %%
nx.draw(G_sylb_3_3)

# %%
caliLoveGraph.add_node(G_sylb_3_3)
caliLoveGraph.add_edge(G_sylb_3_2, G_sylb_3_3, weight = 0)

# %%
G_sylb_3_4 = nx.Graph()
G_sylb_3_4.add_node(3)
G_sylb_3_4.add_node(0)
G_sylb_3_4.add_node("jə")
G_sylb_3_4.add_edge(0,3)
G_sylb_3_4.add_edge("jə",3)
G_sylb_3_4.add_edge("jə", 0)

# %%
nx.draw(G_sylb_3_4)

# %%
caliLoveGraph.add_node(G_sylb_3_4)
caliLoveGraph.add_edge(G_sylb_3_3, G_sylb_3_4, weight = 0)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw(caliLoveGraph, pos, with_labels=False, connectionstyle='arc3, rad = 0.1')

# %%
G_sylb_3_5 = nx.Graph()
G_sylb_3_5.add_node(1)
G_sylb_3_5.add_node(3)
G_sylb_3_5.add_node("ir")
G_sylb_3_5.add_edge("ir", 1)
G_sylb_3_5.add_edge("ir", 3)
G_sylb_3_5.add_edge(1,3)

# %%
caliLoveGraph.add_node(G_sylb_3_5)
caliLoveGraph.add_edge(G_sylb_3_4, G_sylb_3_5, weight = 0)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw(caliLoveGraph, pos, with_labels=False, connectionstyle='arc3, rad = 0.1')

# %%
G_sylb_3_6 = nx.Graph()
G_sylb_3_6.add_node(3)
G_sylb_3_6.add_node(1)
G_sylb_3_6.add_node("drəm")
G_sylb_3_6.add_edge(1,3)
G_sylb_3_6.add_edge("drəm",3)
G_sylb_3_6.add_edge("drəm",1)

# %%
nx.draw(G_sylb_3_6)

# %%
caliLoveGraph.add_node(G_sylb_3_6)

# %%
caliLoveGraph.add_edge(G_sylb_3_5, G_sylb_3_6, weight = 0)

# %%
G_sylb_3_7 = nx.Graph()
G_sylb_3_7.add_node("laIk")
G_sylb_3_7.add_node(3)
G_sylb_3_7.add_node(1)
G_sylb_3_7.add_edge(1,3)
G_sylb_3_7.add_edge("laIk", 3)
G_sylb_3_7.add_edge("laIk", 1)

# %%
caliLoveGraph.add_node(G_sylb_3_7)
caliLoveGraph.add_edge(G_sylb_3_6, G_sylb_3_7, weight = 0)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw(caliLoveGraph, pos, with_labels=False, connectionstyle='arc3, rad = 0.1')

# %%
len(caliLoveGraph.out_edges(G_sylb_14))
# Out:
# 2

# %%
G_sylb_3_8 = nx.Graph()
G_sylb_3_8.add_node("ə")
G_sylb_3_8.add_node(3)
G_sylb_3_8.add_node(0)
G_sylb_3_8.add_edge(0,3)
G_sylb_3_8.add_edge("ə",3)
G_sylb_3_8.add_edge("ə",0)

# %%
caliLoveGraph.add_node(G_sylb_3_8)
caliLoveGraph.add_edge(G_sylb_3_7, G_sylb_3_8, weight = 0)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw(caliLoveGraph, pos, with_labels=False, connectionstyle='arc3, rad = 0.1')

# %%
G_new = nx.Graph()
G_new.add_node(caliLoveGraph)

# %%
G_sylb_3_9 = nx.Graph()
G_sylb_3_9.add_node(3)
G_sylb_3_9.add_node(1)
G_sylb_3_9.add_node("sləg")
G_sylb_3_9.add_edge("sləg", 1)
G_sylb_3_9.add_edge("sləg", 3)
G_sylb_3_9.add_edge(1,3)
nx.draw(G_sylb_3_9)

# %%
caliLoveGraph.add_node(G_sylb_3_9)
caliLoveGraph.add_edge(G_sylb_3_8, G_sylb_3_9, weight = 0)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw(caliLoveGraph, pos, with_labels=False, connectionstyle='arc3, rad = 0.1')

# %%
G_sylb_3_10 = nx.Graph()
G_sylb_3_10.add_node(3)
G_sylb_3_10.add_node(0)
G_sylb_3_10.add_node("tu")
G_sylb_3_10.add_edge(0,3)
G_sylb_3_10.add_edge("tu", 0)
G_sylb_3_10.add_edge("tu", 3)

# %%
caliLoveGraph.add_node(G_sylb_3_10)
caliLoveGraph.add_edge(G_sylb_3_9, G_sylb_3_10, weight = 0)

# %%
G_sylb_3_11 = nx.Graph()
G_sylb_3_11.add_node(3)
G_sylb_3_11.add_node(0)
G_sylb_3_11.add_node("jə")
G_sylb_3_11.add_edge(3,0)
G_sylb_3_11.add_edge("jə",3)
G_sylb_3_11.add_edge("jə",0)

# %%
caliLoveGraph.add_node(G_sylb_3_11)

# %%
caliLoveGraph.add_edge(G_sylb_3_10, G_sylb_3_11, weight = 0)

# %%
G_sylb_3_12 = nx.Graph()
G_sylb_3_12.add_node(3)
G_sylb_3_12.add_node(1)
G_sylb_3_12.add_node("tʃɜst")
G_sylb_3_12.add_edge(3,1)
G_sylb_3_12.add_edge("tʃɜst", 3)
G_sylb_3_12.add_edge("tʃɜst",1)

# %%
caliLoveGraph.add_node(G_sylb_3_12)
caliLoveGraph.add_edge(G_sylb_3_11, G_sylb_3_12, weight = 0)
caliLoveGraph.add_edge(G_sylb_14, G_sylb_3_12, weight = 1)
caliLoveGraph.add_edge(G_sylb_26, G_sylb_3_12, weight = 1)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw(caliLoveGraph, pos, with_labels=False, connectionstyle='arc3, rad = 0.1')

# %%
G_sylb_4_1 = nx.Graph()
G_sylb_4_1.add_node("pæk")
G_sylb_4_1.add_node(4)
G_sylb_4_1.add_node(1)
G_sylb_4_1.add_edge(1,4)
G_sylb_4_1.add_edge("pæk",1)
G_sylb_4_1.add_edge("pæk",4)

# %%
caliLoveGraph.add_node(G_sylb_4_1)
caliLoveGraph.add_edge(G_sylb_3_12, G_sylb_4_1, weight = 0)

# %%
options = {
    'node_color': 'blue',
    'node_size': 100,
    'width': 3,
    'arrowstyle': '-|>',
    'arrowsize': 12,
}

# %%
nx.draw(G_sylb_3_1, with_labels = True)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw_networkx(caliLoveGraph, pos, with_labels=False, connectionstyle='arc3, rad = 0.1')

# %%
G_sylb_4_2 = nx.Graph()
G_sylb_4_2.add_node(0)
G_sylb_4_2.add_node("ə")
G_sylb_4_2.add_node(4)
G_sylb_4_2.add_edge(0,4)
G_sylb_4_2.add_edge("ə", 4)
G_sylb_4_2.add_edge("ə", 0)

# %%
nx.draw(G_sylb_4_2)

# %%
caliLoveGraph.add_node(G_sylb_4_2)
caliLoveGraph.add_edge(G_sylb_4_1, G_sylb_4_2, weight = 0)

# %%
G_sylb_4_3 = nx.Graph()
G_sylb_4_3.add_node(1)
G_sylb_4_3.add_node("vɜst")
G_sylb_4_3.add_node(4)
G_sylb_4_3.add_edge(1,4)
G_sylb_4_3.add_edge("vɜst", 4)
G_sylb_4_3.add_edge("vɜst", 1)

# %%
caliLoveGraph.add_node(G_sylb_4_3)
caliLoveGraph.add_edge(G_sylb_4_2, G_sylb_4_3, weight = 0)
caliLoveGraph.add_edge(G_sylb_14, G_sylb_4_3, weight = 1)
caliLoveGraph.add_edge(G_sylb_26, G_sylb_4_3, weight = 1)
caliLoveGraph.add_edge(G_sylb_3_12, G_sylb_4_3, weight = 1)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw_networkx(caliLoveGraph, pos, with_labels=False, connectionstyle='arc3, rad = 0.1')

# %%
G_sylb_4_4 = nx.Graph()
G_sylb_4_4.add_node("fɜ˞")
G_sylb_4_4.add_node(1)
G_sylb_4_4.add_node(4)
G_sylb_4_4.add_edge(1,4)
G_sylb_4_4.add_edge("fɜ˞", 4)
G_sylb_4_4.add_edge("fɜ˞", 1)

# %%
caliLoveGraph.add_node(G_sylb_4_4)
caliLoveGraph.add_edge(G_sylb_4_3, G_sylb_4_4, weight = 0)

# %%
G_sylb_4_5 = nx.Graph()
G_sylb_4_5.add_node("jɜ˞")
G_sylb_4_5.add_node(0)
G_sylb_4_5.add_node(4)
G_sylb_4_5.add_edge(0,4)
G_sylb_4_5.add_edge(0, "jɜ˞")
G_sylb_4_5.add_edge(4, "jɜ˞")
caliLoveGraph.add_node(G_sylb_4_5)
caliLoveGraph.add_edge(G_sylb_4_4, G_sylb_4_5, weight = 0)

# %%
G_sylb_4_6 = nx.Graph()
G_sylb_4_6.add_node("dʒI")
G_sylb_4_6.add_node(1)
G_sylb_4_6.add_node(4)
G_sylb_4_6.add_edge(1,4)
G_sylb_4_6.add_edge("dʒI", 4)
G_sylb_4_6.add_edge("dʒI", 1)
caliLoveGraph.add_node(G_sylb_4_6)
caliLoveGraph.add_edge(G_sylb_4_5, G_sylb_4_6, weight = 0)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw_networkx(caliLoveGraph, pos, with_labels = False)

# %%
G_sylb_4_7 = nx.Graph()
G_sylb_4_7.add_node("mi")
G_sylb_4_7.add_node(4)
G_sylb_4_7.add_node(0)
G_sylb_4_7.add_edge(0,4)
G_sylb_4_7.add_edge("mi", 4)
G_sylb_4_7.add_edge("mi", 0)
caliLoveGraph.add_node(G_sylb_4_7)
caliLoveGraph.add_edge(G_sylb_4_6, G_sylb_4_7, weight = 0)

# %%
G_sylb_4_8 = nx.Graph()
G_sylb_4_8.add_node(1)
G_sylb_4_8.add_node(4)
G_sylb_4_8.add_node("In")
G_sylb_4_8.add_edge("In", 4)
G_sylb_4_8.add_edge("In", 1)
caliLoveGraph.add_node(G_sylb_4_8)
caliLoveGraph.add_edge(G_sylb_4_7, G_sylb_4_8, weight = 0)

# %%
G_sylb_4_9 = nx.Graph()
G_sylb_4_9.add_node(0)
G_sylb_4_9.add_node("ðə")
G_sylb_4_9.add_node(4)
G_sylb_4_9.add_edge(0,4)
G_sylb_4_9.add_edge("ðə", 4)
G_sylb_4_9.add_edge("ðə", 0)
caliLoveGraph.add_node(G_sylb_4_9)
caliLoveGraph.add_edge(G_sylb_4_8, G_sylb_4_9, weight = 0)

# %%
G_sylb_4_10 = nx.Graph()
G_sylb_4_10.add_node(1)
G_sylb_4_10.add_node(4)
G_sylb_4_10.add_node("sI")
G_sylb_4_10.add_edge(1,4)
G_sylb_4_10.add_edge("sI", 4)
G_sylb_4_10.add_edge("sI", 1)
caliLoveGraph.add_node(G_sylb_4_10)
caliLoveGraph.add_edge(G_sylb_4_9, G_sylb_4_10, weight = 0)
caliLoveGraph.add_edge(G_sylb_4_6, G_sylb_4_10, weight = 1)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw_networkx(caliLoveGraph, pos, with_labels=False, connectionstyle='arc3, rad = 0.1')

# %%
G_sylb_4_11 = nx.Graph()
G_sylb_4_11.add_node(0)
G_sylb_4_11.add_node("ti")
G_sylb_4_11.add_node(4)
G_sylb_4_11.add_edge(0,4)
G_sylb_4_11.add_edge("ti", 4)
G_sylb_4_11.add_edge("ti", 0)
caliLoveGraph.add_node(G_sylb_4_11)

# %%
caliLoveGraph.add_edge(G_sylb_4_10, G_sylb_4_11, weight = 0)
caliLoveGraph.add_edge(G_sylb_4_7, G_sylb_4_11, weight = 1)

# %%
G_sylb_4_12 = nx.Graph()
G_sylb_4_12.add_node("əv")
G_sylb_4_12.add_node(4)
G_sylb_4_12.add_node(0)
G_sylb_4_12.add_edge(0,4)
G_sylb_4_12.add_edge("əv", 4)
G_sylb_4_12.add_edge("əv", 0)
caliLoveGraph.add_node(G_sylb_4_12)

# %%
caliLoveGraph.add_edge(G_sylb_4_11, G_sylb_4_12, weight = 0)

# %%
G_sylb_4_13 = nx.Graph()
G_sylb_4_13.add_node("sɜks")
G_sylb_4_13.add_node(1)
G_sylb_4_13.add_node(4)
G_sylb_4_13.add_edge(1,4)
G_sylb_4_13.add_edge("sɜks", 4)
G_sylb_4_13.add_edge("sɜks", 1)
caliLoveGraph.add_node(G_sylb_4_13)
caliLoveGraph.add_edge(G_sylb_4_12, G_sylb_4_13, weight = 0)
caliLoveGraph.add_edge(G_sylb_14, G_sylb_4_13, weight = 1)
caliLoveGraph.add_edge(G_sylb_26, G_sylb_4_13, weight = 1)
caliLoveGraph.add_edge(G_sylb_3_12, G_sylb_4_13, weight = 1)
caliLoveGraph.add_edge(G_sylb_4_3, G_sylb_4_13, weight = 1)

# %%
pos = nx.spring_layout(caliLoveGraph)
nx.draw_networkx(caliLoveGraph, pos, with_labels=False, connectionstyle='arc3, rad = 0.1')

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(30, 30)) 
nx.draw(caliLoveGraph, pos=nx.circular_layout(caliLoveGraph), node_size=300, font_size = 10) 
plt.axis('equal') 
plt.show()
# add rhythm - each edge has weight of timing
# separate class of edges for rhyme and for timing
# circular graph in time order
# try different models of graphs and see which ones work best?
# collapse two syllables that are grouped together? if its AB AB B don't collapse. each node could have a number
# of syllables property
# try to automate
# rhyme identification ultimately, if i don't know what the rhyme is how do i find them? what are some other connections? 
# these syllables are connected if same duration, same beat, etc. (multiple edges - connection if same rhythm, same measure, same stress, same phoneme,etc...
# how do we group together? three syllables in a row, two syllables, same rhythm (chunk) etc. - frontier (think about this-parentheses - collapse?)
# rhythm, stress, phoneme, syllable number in phrase, metric position, prosodic boundary, is it subject? is it noun vs. verb?

# %%
# with open('stress_caliLove.txt') as f:
#     lines = f.readlines()
import pandas as pd
import numpy as np
stress_list = pd.read_csv("stress_caliLove.csv")
stress_list_df = pd.DataFrame(stress_list)
stress_list_df = stress_list_df.replace('', np.nan, inplace=True)
stress_list_df = stress_list_df.dropna()
print(stress_list)
phoneme_list = ["i"]*417
phrase_list = [2]*417
caliLoveFull = nx.DiGraph()
for i in range(0,417):
    stress_list.append()
    graph = nx.Graph()
    graph.add_node(stress_list[i])
    graph.add_node(phoneme_list[i])
    graph.add_node(phrase_list[i])
    graph.add_edge(stress_list[i], phoneme_list[i])
    graph.add_edge(stress_list[i], phrase_list[i])
    graph.add_edge(phrase_list[i], phoneme_list[i])
    caliLoveFull.add_node(graph)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-309-f3588603387f> in <module>
#       6 stress_list_df = pd.DataFrame(stress_list)
#       7 stress_list_df = stress_list_df.replace('', np.nan, inplace=True)
# ----> 8 stress_list_df = stress_list_df.dropna()
#       9 print(stress_list)
#      10 phoneme_list = ["i"]*417
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
len(list(directed_graph.nodes))
# Out:
# 72121

# %%
for i in range(len(list(directed_graph.nodes))):
    if(i >= 1):
        directed_graph.add_edge(list(directed_graph.nodes)[i-1], list(directed_graph.nodes)[i])

# %%
pos = nx.circular_layout(directed_graph)
nx.draw_networkx(directed_graph, pos, with_labels = False)
# semantic connections too? semantic networks of hip hop
# phrases could be nodes
# each beat is a node?
# try multiple versions and see what works best
# one network which is single syllable and another which is bigram for same song (two syllables in one node)
# 1, 2, 3, 4, 5 gram versions. trim away connections 3->2->1. or start with phrase level. any phrase that's similar keep
# keep thinking is there a better solution than syllable level. how do we move to bigger chunks?
# do syllable for baseline, then try the same thing at 2 gram level, 3 gram level, etc. add duration. 
# try if both syllables rhyme and if one syllable rhymes. can break it into foots in poetry. 
# take each stressed syllable, and attach the next unstressed syllable.
# explore ways of looking at words and look at stress patterns and make chunks that way. if its a 3 syllable word make
# it a chunk otherwise if its a one syllable word do it based on stress
